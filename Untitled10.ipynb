# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheshkhule/AI-Fashion-Project-FASHN-VTON-v1.5-Implementation/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CELL 1 — Clone Repo

# %%
# !git clone https://github.com/fashn-AI/fashn-vton-1.5.git
# %cd fashn-vton-1.5
# Out:
# Cloning into 'fashn-vton-1.5'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 92 (delta 20), reused 13 (delta 13), pack-reused 67 (from 1)
# Receiving objects: 100% (92/92), 334.44 KiB | 1.78 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/fashn-vton-1.5

# %% [markdown]
# CELL 2 — Check Structure

# %%
# !find . -maxdepth 3 -type d
# Out:
# .
# ./scripts
# ./.git
# ./.git/branches
# ./.git/info
# ./.git/refs
# ./.git/refs/heads
# ./.git/refs/tags
# ./.git/refs/remotes
# ./.git/objects
# ./.git/objects/info
# ./.git/objects/pack
# ./.git/hooks
# ./.git/logs
# ./.git/logs/refs
# ./examples
# ./examples/data
# ./src
# ./src/fashn_vton
# ./src/fashn_vton/utils
# ./src/fashn_vton/dwpose
# ./src/fashn_vton/preprocessing
# ./tests

# %% [markdown]
# CELL 3 — Install Dependencies

# %%
# !pip install -r requirements.txt

# !pip install xformers accelerate
# !pip install opencv-python pillow matplotlib
# !pip install onnxruntime-gpu
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 MB 4.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# CELL 4 — FIX PYTHON PATH (IMPORTANT)

# %%
import sys
sys.path.append("/content/fashn-vton-1.5/src")

# %% [markdown]
# CELL 5 — Test Import

# %%
from fashn_vton import TryOnPipeline

print("Import Successful")
# Out:
# Import Successful

# %%
# !pip install -q fashn-human-parser

# %% [markdown]
# CELL 6 — Download Weights

# %%
# !python scripts/download_weights.py --weights-dir ./weights
# Out:
# ...
#
# ...
# model.safetensors: 100% 1.94G/1.94G [00:16<00:00, 120MB/s]
#   Saved to: /content/fashn-vton-1.5/weights/model.safetensors
#
# ...
# yolox_l.onnx: 100% 217M/217M [00:02<00:00, 83.0MB/s]
#   Saved to: /content/fashn-vton-1.5/weights/dwpose/yolox_l.onnx
# ...
# dw-ll_ucoco_384.onnx: 100% 134M/134M [00:02<00:00, 51.4MB/s]
#   Saved to: /content/fashn-vton-1.5/weights/dwpose/dw-ll_ucoco_384.onnx
#
# ...
# config.json: 1.65kB [00:00, 4.55MB/s]
# model.safetensors: 100% 256M/256M [00:04<00:00, 63.7MB/s]
# Loading weights: 100% 930/930 [00:01<00:00, 712.55it/s, Materializing param=segformer.encoder.patch_embeddings.3.proj.weight]
#   Cached in HuggingFace hub cache
#
# Download complete!
#
# Weights directory structure:
#     /content/fashn-vton-1.5/weights/
#     ├── model.safetensors
#     └── dwpose/
#         ├── yolox_l.onnx
#         └── dw-ll_ucoco_384.onnx
#
# Usage:
#     from fashn_vton import TryOnPipeline
#     pipeline = TryOnPipeline(weights_dir="/content/fashn-vton-1.5/weights")

# %% [markdown]
# CELL 7 — Upload Images

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b4304a0f-471a-412a-b88e-c801b7119b90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4304a0f-471a-412a-b88e-c801b7119b90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# CELL 8 — Run Inference

# %%
from fashn_vton import TryOnPipeline
from PIL import Image
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

print("Using:", device)

pipeline = TryOnPipeline(
    weights_dir="./weights",
    device=device
)

person = Image.open("person.jpg").convert("RGB")
garment = Image.open("garment.jpg").convert("RGB")

# optional resize
person = person.resize((576,864))
garment = garment.resize((576,864))

result = pipeline(
    person_image=person,
    garment_image=garment,
    category="tops",
    garment_photo_type="flat-lay",
    num_samples=1,
    num_timesteps=30,
    guidance_scale=1.5,
    seed=42,
    segmentation_free=True
)

result.images[0].save("output.png")

print("DONE")
# Out:
# TryOnPipeline - INFO - Using device: cuda
# Using: cuda
# TryOnPipeline - INFO - Using dtype: torch.bfloat16
# TryOnPipeline - INFO - Loading TryOnModel from /content/fashn-vton-1.5/weights/model.safetensors
# TryOnPipeline - INFO - TryOnModel loaded
# TryOnPipeline - INFO - Loading DWPose from /content/fashn-vton-1.5/weights/dwpose
# TryOnPipeline - INFO - DWPose loaded
# TryOnPipeline - INFO - Loading FashnHumanParser
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %% [markdown]
# CELL 9 — Show Output

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("output.png")

plt.figure(figsize=(8,12))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# CELL 10 — Download Output

# %%
files.download("output.png")

# %%
# Go to repo
# %cd /content/fashn-vton-1.5

# Add source path
import sys
sys.path.insert(0, "/content/fashn-vton-1.5/src")

# Import
from fashn_vton import TryOnPipeline

print("Import Successful")

# %%
pipeline = TryOnPipeline(
    weights_dir="./weights",
    device="cuda"
)

print("Pipeline Loaded")

# %%
# %cd /content/fashn-vton-1.5

# !python scripts/download_weights.py --weights-dir ./weights
# Out:
# [Errno 2] No such file or directory: '/content/fashn-vton-1.5'
# /content
# python3: can't open file '/content/scripts/download_weights.py': [Errno 2] No such file or directory
